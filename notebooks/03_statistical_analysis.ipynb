# %% [markdown]
# # 03_statistical_analysis
#
# This notebook conducts formal hypothesis testing on relationships identified in `02_eda.ipynb`. The statistical significance of correlations between air pollutants such as PM2.5 and health risks will be tested.

# %%
# Setup and imports 
import pandas as pd 
import numpy as np 
from scipy import stats
